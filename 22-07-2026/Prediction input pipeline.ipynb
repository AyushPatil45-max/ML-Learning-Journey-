# %%
import pickle
import numpy as np

# %%
pipline = pickle.load(open('pipe.pkl','rb'))

# %%
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
import pandas as pd

test_input = pd.DataFrame({
    'Pclass': [2],
    'Sex': ['male'],
    'Age': [31.0],
    'SibSp': [0],
    'Parch': [0],
    'Fare': [10.5],
    'Embarked': ['S']
})

prediction = pipline.predict(test_input)
print(prediction)
# Out:
# [0]
